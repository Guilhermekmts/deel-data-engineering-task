# %% [markdown]
# # DEEL Spark CDC Exploration Notebook
# This notebook runs inside the Spark container and can query both Kafka CDC topics and the final analytics layer in Postgres.

# %%
import os
from pyspark.sql import SparkSession
from delta.pip_utils import configure_spark_with_delta_pip

builder = (
    SparkSession.builder
    .appName("deel-notebook")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
)
spark = configure_spark_with_delta_pip(builder).getOrCreate()
spark.sparkContext.setLogLevel("ERROR")
spark
# Out:
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/spark/.ivy2/cache
# The jars for the packages stored in: /home/spark/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-429ffad6-62d5-4521-bc85-86c9f4f0fe13;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.2.0 in central
# 	found io.delta#delta-storage;3.2.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# downloading https://repo1.maven.org/maven2/io/delta/delta-spark_2.12/3.2.0/delta-spark_2.12-3.2.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-spark_2.12;3.2.0!delta-spark_2.12.jar (746ms)
# downloading https://repo1.maven.org/maven2/io/delta/delta-storage/3.2.0/delta-storage-3.2.0.jar ...
# 	[SUCCESSFUL ] io.delta#delta-storage;3.2.0!delta-storage.jar (151ms)
# downloading https://repo1.maven.org/maven2/org/antlr/antlr4-runtime/4.9.3/antlr4-runtime-4.9.3.jar ...
# 	[SUCCESSFUL ] org.antlr#antlr4-runtime;4.9.3!antlr4-runtime.jar (106ms)
# :: resolution report :: resolve 1575ms :: artifacts dl 1008ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.2.0 from central in [default]
# 	io.delta#delta-storage;3.2.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   3   |   3   |   0   ||   3   |   3   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-429ffad6-62d5-4521-bc85-86c9f4f0fe13
# 	confs: [default]
# 	3 artifacts copied, 0 already retrieved (6321kB/15ms)
# 26/06/27 14:51:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://c31493d84257:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>deel-notebook</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Query Delta silver table

# %%
delta_path = os.getenv("DELTA_ROOT", "/workspace/data/delta") + "/silver_orders"
orders_df = spark.read.format("delta").load(delta_path)
orders_df.count()
# Out:
# 342

# %%
delta_path = os.getenv("DELTA_ROOT", "/workspace/data/delta") + "/current/customers"
orders_items = spark.read.format("delta").load(delta_path)
orders_items.count()
# Out:
# 0
